# %% [markdown]
# # Cross-validation
# Learning the parameters of a prediction function and testing it on the same data is a methodological mistake: a model that would just repeat the labels of the samples that it has just seen would have a perfect score but would fail to predict anything useful on yet-unseen data. This situation is called overfitting. To avoid it, it is common practice when performing a (supervised) machine learning experiment **to hold out part of the available data as a test set X_test, y_test.**

# %% [markdown]
# ## Part 1: Training The Model
# Execute the cell below. It generates train and dataset. You can observe each of them separately.

# %%
from matplotlib import pyplot as plt
from sklearn.datasets import make_moons
from sklearn.preprocessing import StandardScaler
import numpy as np

# DO NOT MODIFY THIS FUNCTION
def generate_nonlinear_dataset():
  def make_double_moon(seed, size):
    X1, y1 = make_moons(n_samples = size, noise=0.30, random_state=seed)
    X2, y2 = make_moons(n_samples = size, noise=0.20, random_state=seed)

    X1[y1==0] += [0, 0.2]
    X2[y2==0] += [0, 0.1]
    y2 = 1 - y2

    return (
        np.concatenate([X1, X2 + [3.5, 1.5]]),
        np.concatenate([y1, y2])
    )

  X_train, y_train = make_double_moon(42, 50)
  X_test, y_test = make_double_moon(12, 100)

  return (X_train, y_train, X_test, y_test)


# DO NOT MODIFY THIS FUNCTION
def plot_dataset(X, y, axes):
    plt.plot(X[:, 0][y==0], X[:, 1][y==0], "bs")
    plt.plot(X[:, 0][y==1], X[:, 1][y==1], "g^")
    plt.axis(axes)
    plt.grid(True, which='both')
    plt.xlabel(r"$x_1$", fontsize=20)
    plt.ylabel(r"$x_2$", fontsize=20, rotation=0)


plot_axes = [-2.5, 7, -2, 3]
X_train, y_train, X_test, y_test = generate_nonlinear_dataset()

plot_dataset(X_train, y_train, plot_axes)
plt.show()
plot_dataset(X_test, y_test, plot_axes)
plt.show()

# %% [markdown]
# Now, complete the pipeline by putting a linear SVM classifier at the end. Then fit the model to the train dataset and see how the classifier performed on the train dataset. Feel free to tune the parameters of the classifier as they best suit the data.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

# COMPLETE THE PIPELINE
polynomial_svm_clf = Pipeline([
        ("poly_features", PolynomialFeatures(degree=50)),
        ("scaler", StandardScaler()),
])


# FIT YOUR MODEL HERE
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ''

# %%
# DO NOT MODIFY THIS FUNCTION
def plot_predictions(clf, axes):
    x0s = np.linspace(axes[0], axes[1], 100)
    x1s = np.linspace(axes[2], axes[3], 100)
    x0, x1 = np.meshgrid(x0s, x1s)
    X = np.c_[x0.ravel(), x1.ravel()]
    y_pred = clf.predict(X).reshape(x0.shape)
    y_decision = clf.decision_function(X).reshape(x0.shape)
    plt.contourf(x0, x1, y_pred, cmap=plt.cm.brg, alpha=0.2)
    plt.contourf(x0, x1, y_decision, cmap=plt.cm.brg, alpha=0.1)

# train dataset classification
plot_predictions(polynomial_svm_clf, plot_axes)
plot_dataset(X_train, y_train, plot_axes)
plt.show()

# test dataset classification
plot_predictions(polynomial_svm_clf, plot_axes)
plot_dataset(X_test, y_test, plot_axes)
plt.show()

# %% [markdown]
# ## Part 2: Measuring the Performance of a Classifier
#
# Write code to measure the accuracy (number of correctly classified examples) for a classifier on the given dataset (X,y):

# %%
def accuracy(classifier, X, y):
  pass # WRITE YOUR CODE HERE

# TODO: make sure the above code (with completed accuracy function) actually
# overfits when C and degree are too high.

# %% [markdown]
# Using the function you've just completed, calculate the train and test accuracy of the SVM you trained.
#
# Then, increase the *C* and *degree* arguments when constructing the classifier and train it again. How do train and test accuracy change?

# %%
# WRITE YOUR CODE HERE

# %% [markdown]
# Plot the decision boundary for the classifiers with higher *C* and *degree*.
# Can you now explain why you obtained the previous results about the train
# and test accuracy ?

# %%
# WRITE YOUR CODE HERE
